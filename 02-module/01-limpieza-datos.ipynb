# %% [markdown]
# # Importar librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Carga y descripción

# %%
df = pd.read_excel("data/data-covid.xlsx")

# %%
df.head()
# Out:
#      id   ano  semana   fecha_not diresa        red       microred  \
# 0   542  2021       5  09-02-2021   PUNO       PUNO   SIN MICRORED
# 1  1234  2020      10  07-03-2020   PUNO  SAN ROMAN   SIN MICRORED
# 2  1258  2020      10  09-03-2020   PUNO       PUNO   SIN MICRORED
# 3  1266  2020      10  09-03-2020   PUNO  SAN ROMAN   SIN MICRORED
# 4  1292  2021       9  05-03-2021   PUNO       PUNO  METROPOLITANO
#
#                            establecimiento        institucion clasificacion  \
# 0  HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO  GOBIERNO REGIONAL    DESCARTADO
# 1   HOSP. "CARLOS MONGE MEDRANO" - JULIACA  GOBIERNO REGIONAL    DESCARTADO
# 2                  HOSPITAL III DE ESSALUD            ESSALUD    DESCARTADO
# 3   HOSP. "CARLOS MONGE MEDRANO" - JULIACA  GOBIERNO REGIONAL    DESCARTADO
# 4                  C.S. METROPOLITANO PUNO  GOBIERNO REGIONAL    CONFIRMADO
#
#    ... prueba_rap resultado_rap fecha_res_rap  fecha_rap1  muestra_rap1  \
# 0  ...        NaN           NaN           NaN  00-00-0000           NaN
# 1  ...        NaN           NaN           NaN         NaN           NaN
# 2  ...        NaN           NaN           NaN         NaN           NaN
# 3  ...        NaN           NaN           NaN         NaN           NaN
# 4  ...  SEROLOGIA      NEGATIVO    16-07-2020  00-00-0000           NaN
#
#   prueba_rap1 resultado_rap1 fecha_res_rap1  secuenciamiento  asintomatico
# 0         NaN            NaN            NaN              NaN           NaN
# 1         NaN            NaN            NaN              NaN           NaN
# 2         NaN            NaN            NaN              NaN           NaN
# 3         NaN            NaN            NaN              NaN           NaN
# 4         NaN            NaN            NaN              NaN           NaN
#
# [5 rows x 190 columns]

# %%
print("Número de registros:", df.shape[0])
print("Número de columnas: ", df.shape[1])
# Out:
# Número de registros: 95315
# Número de columnas:  190

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95315 entries, 0 to 95314
# Columns: 190 entries, id to asintomatico
# dtypes: float64(32), int64(39), object(119)
# memory usage: 138.2+ MB

# %% [markdown]
# # Limpieza de datos

# %% [markdown]
# ## Eliminar datos nulos

# %%
# Calcular el porcentaje de datos nulos por columna
porcentaje_nulos = (df.isna().sum() / len(df)) * 100

# Crear un DataFrame con la información de porcentaje de nulos
info_nulos = pd.DataFrame({'Columna': df.columns, 'Porcentaje Nulos': porcentaje_nulos}).reset_index(drop=True)

print(info_nulos.sort_values(by='Porcentaje Nulos', ascending=False))
# Out:
#                      Columna  Porcentaje Nulos
# 188          secuenciamiento        100.000000
# 53                  otro_hos        100.000000
# 31                otra_etnia         99.984263
# 65                 otros_def         99.847873
# 131                 ciudad_3         99.846824
# 143                    caso3         99.836332
# 12                   entrada         99.643288
# 139            contacto_otro         99.619158
# 54      otro_hos_especificar         99.501652
# 56             servicio_otro         99.284478
# 142                    caso2         99.260347
# 176               resultado2         99.191103
# 175                  prueba2         99.163825
# 174                 muestra2         99.163825
# 129                 ciudad_2         99.100876
# 151             entorno_otro         99.069401
# 66             clasifica_def         98.197555
# 116                profesion         98.063264
# 162        mercado_localidad         97.964644
# 120             eess_trabajo         97.902744
# 160        provincia_mercado         97.897498
# 161         contacto_mercado         97.897498
# 159     departamento_mercado         97.897498
# 119         microred_trabajo         97.870220
# 64                 lugar_def         97.531343
# 118              red_trabajo         97.492525
# 117           diresa_trabajo         97.469443
# 55                  servicio         97.284793
# 42           diagnostico_ing         97.140009
# 121     departamento_trabajo         96.479043
# 122        provincia_trabajo         96.479043
# 123         distrito_trabajo         96.479043
# 124           ubigeo_trabajo         96.132823
# 41                    seguro         95.995384
# 133                esalud_14         95.956565
# 171               resultado1         95.743587
# 30             pueblo_etnico         95.685884
# 170                  prueba1         95.658606
# 169                 muestra1         95.632377
# 84            otros_sintomas         94.255888
# 40                      eess         93.752295
# 59                  neumonia         93.312700
# 58                  entubado         93.204637
# 156       contacto_localidad         92.795468
# 185              prueba_rap1         92.548917
# 127                 ciudad_1         92.532130
# 141                    caso1         92.433510
# 155          contacto_ubigeo         92.414625
# 154       provincia_contacto         92.414625
# 153    departamento_contacto         92.414625
# 187           fecha_res_rap1         92.410429
# 186           resultado_rap1         92.395740
# 184             muestra_rap1         92.392593
# 96              otros_signos         88.234800
# 22                  migrante         85.910927
# 112       otros_comorbilidad         85.102030
# 34    departamento_infeccion         80.850863
# 35       provincia_infeccion         80.850863
# 36        distrito_infeccion         80.850863
# 37          ubigeo_infeccion         80.553953
# 20              nacionalidad         75.178094
# 60                 evolucion         70.793684
# 50             ecografia_hos         66.004302
# 45            convulsion_hos         66.004302
# 47                  coma_hos         66.003252
# 52                   rmn_hos         66.003252
# 51            tomografia_hos         66.000105
# 49           radiografia_hos         65.967581
# 46                disnea_hos         65.964434
# 48          auscultacion_hos         65.952893
# 57               ventilacion         64.835545
# 166                resultado         61.349211
# 109                 obesidad         61.079578
# 93                 ecografia         61.079578
# 81                   anosmia         61.079578
# 110                      tbc         61.079578
# 111                     asma         61.079578
# 113         culmina_embarazo         61.079578
# 83                      oido         61.079578
# 82                   ageusia         61.079578
# 95                       rmn         61.079578
# 63                  hora_def         61.079578
# 147              casa_reposo         61.079578
# 61                 fecha_alt         61.079578
# 148     centro_penitenciario         61.079578
# 149                 albergue         61.079578
# 23               pais_origen         61.079578
# 21         pais_nacionalidad         61.079578
# 19                     talla         61.079578
# 18                      peso         61.079578
# 173               fecha_mue2         61.079578
# 177               fecha_res2         61.079578
# 94                tomografia         61.079578
# 165                   prueba         60.545559
# 164                  muestra         59.854168
# 189             asintomatico         59.114515
# 10                     punto         51.499764
# 180               prueba_rap         35.874731
# 157                  mercado         35.247338
# 182            fecha_res_rap         34.719614
# 179              muestra_rap         34.220217
# 181            resultado_rap         34.189792
# 115           otra_ocupacion         33.167917
# 183               fecha_rap1         30.067670
# 178                fecha_rap         30.066621
# 158             mercado_pais         30.055081
# 125               viajado_14         30.055081
# 126                   pais_1         30.055081
# 43               aislamiento         30.055081
# 85               temperatura         30.055081
# 138     contacto_desconocido         30.055081
# 130                   pais_3         30.055081
# 137         contacto_trabajo         30.055081
# 132                  eess_14         30.055081
# 134              contacto_14         30.055081
# 128                   pais_2         30.055081
# 11                 fecha_det         30.055081
# 135           contacto_salud         30.055081
# 152            contacto_pais         30.055081
# 89                      coma         30.055081
# 106                 hepatico         30.055081
# 136        contacto_familiar         30.055081
# 29                     etnia         16.322719
# 6                   microred          0.101768
# 26      provincia_residencia          0.022032
# 25   departamento_residencia          0.022032
# 27                residencia          0.022032
# 7            establecimiento          0.017836
# 8                institucion          0.017836
# 28                    ubigeo          0.017836
# 168               fecha_mue1          0.010492
# 172               fecha_res1          0.010492
# 9              clasificacion          0.004197
# 32                 direccion          0.000000
# 33                 fecha_ini          0.000000
# 38             hospitalizado          0.000000
# 1                        ano          0.000000
# 163                fecha_mue          0.000000
# 24           pais_residencia          0.000000
# 17                   tipodoc          0.000000
# 16                      sexo          0.000000
# 39                 fecha_hos          0.000000
# 15                 tipo_edad          0.000000
# 14                      edad          0.000000
# 13                    nombre          0.000000
# 5                        red          0.000000
# 4                     diresa          0.000000
# 3                  fecha_not          0.000000
# 2                     semana          0.000000
# 167                fecha_res          0.000000
# 67                    fiebre          0.000000
# 150      entorno_desconocido          0.000000
# 107                 pulmonar          0.000000
# 87               conjuntival          0.000000
# 114                ocupacion          0.000000
# 88                convulsion          0.000000
# 90                    disnea          0.000000
# 91              auscultacion          0.000000
# 92                rxpulmonar          0.000000
# 108                   cancer          0.000000
# 105                    renal          0.000000
# 80            articulaciones          0.000000
# 104        inmunodeficiencia          0.000000
# 103              neurologica          0.000000
# 102                 hepatica          0.000000
# 101                 diabetes          0.000000
# 100           cardiovascular          0.000000
# 99                 postparto          0.000000
# 98                 trimestre          0.000000
# 86                   exudado          0.000000
# 79                     pecho          0.000000
# 44                 fecha_ais          0.000000
# 140            confirmado_14          0.000000
# 62                 fecha_def          0.000000
# 146          entorno_trabajo          0.000000
# 145         entorno_familiar          0.000000
# 144            entorno_salud          0.000000
# 97                  embarazo          0.000000
# 68                  malestar          0.000000
# 69                       tos          0.000000
# 70                  garganta          0.000000
# 78                 abdominal          0.000000
# 71                congestion          0.000000
# 72              respiratoria          0.000000
# 73                   diarrea          0.000000
# 74                   nauseas          0.000000
# 75                   cefalea          0.000000
# 76             irritabilidad          0.000000
# 77                  muscular          0.000000
# 0                         id          0.000000

# %%
# Filtrar las columnas con porcentaje de nulos menor o igual al 40%
columnas_a_mantener = info_nulos[info_nulos['Porcentaje Nulos'] < 40]['Columna']
df2 = df[columnas_a_mantener]
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95315 entries, 0 to 95314
# Data columns (total 93 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       95315 non-null  int64
#  1   ano                      95315 non-null  int64
#  2   semana                   95315 non-null  int64
#  3   fecha_not                95315 non-null  object
#  4   diresa                   95315 non-null  object
#  5   red                      95315 non-null  object
#  6   microred                 95218 non-null  object
#  7   establecimiento          95298 non-null  object
#  8   institucion              95298 non-null  object
#  9   clasificacion            95311 non-null  object
#  10  fecha_det                66668 non-null  object
#  11  nombre                   95315 non-null  object
#  12  edad                     95315 non-null  int64
#  13  tipo_edad                95315 non-null  object
#  14  sexo                     95315 non-null  object
#  15  tipodoc                  95315 non-null  object
#  16  pais_residencia          95315 non-null  object
#  17  departamento_residencia  95294 non-null  object
#  18  provincia_residencia     95294 non-null  object
#  19  residencia               95294 non-null  object
#  20  ubigeo                   95298 non-null  object
#  21  etnia                    79757 non-null  object
#  22  direccion                95315 non-null  object
#  23  fecha_ini                95315 non-null  object
#  24  hospitalizado            95315 non-null  object
#  25  fecha_hos                95315 non-null  object
#  26  aislamiento              66668 non-null  object
#  27  fecha_ais                95315 non-null  object
#  28  fecha_def                95315 non-null  object
#  29  fiebre                   95315 non-null  int64
#  30  malestar                 95315 non-null  int64
#  31  tos                      95315 non-null  int64
#  32  garganta                 95315 non-null  int64
#  33  congestion               95315 non-null  int64
#  34  respiratoria             95315 non-null  int64
#  35  diarrea                  95315 non-null  int64
#  36  nauseas                  95315 non-null  int64
#  37  cefalea                  95315 non-null  int64
#  38  irritabilidad            95315 non-null  int64
#  39  muscular                 95315 non-null  int64
#  40  abdominal                95315 non-null  int64
#  41  pecho                    95315 non-null  int64
#  42  articulaciones           95315 non-null  int64
#  43  temperatura              66668 non-null  float64
#  44  exudado                  95315 non-null  int64
#  45  conjuntival              95315 non-null  int64
#  46  convulsion               95315 non-null  int64
#  47  coma                     66668 non-null  float64
#  48  disnea                   95315 non-null  int64
#  49  auscultacion             95315 non-null  int64
#  50  rxpulmonar               95315 non-null  int64
#  51  embarazo                 95315 non-null  int64
#  52  trimestre                95315 non-null  int64
#  53  postparto                95315 non-null  int64
#  54  cardiovascular           95315 non-null  int64
#  55  diabetes                 95315 non-null  int64
#  56  hepatica                 95315 non-null  int64
#  57  neurologica              95315 non-null  int64
#  58  inmunodeficiencia        95315 non-null  int64
#  59  renal                    95315 non-null  int64
#  60  hepatico                 66668 non-null  float64
#  61  pulmonar                 95315 non-null  int64
#  62  cancer                   95315 non-null  int64
#  63  ocupacion                95315 non-null  object
#  64  otra_ocupacion           63701 non-null  object
#  65  viajado_14               66668 non-null  object
#  66  pais_1                   66668 non-null  object
#  67  pais_2                   66668 non-null  object
#  68  pais_3                   66668 non-null  object
#  69  eess_14                  66668 non-null  object
#  70  contacto_14              66668 non-null  object
#  71  contacto_salud           66668 non-null  float64
#  72  contacto_familiar        66668 non-null  float64
#  73  contacto_trabajo         66668 non-null  float64
#  74  contacto_desconocido     66668 non-null  float64
#  75  confirmado_14            95315 non-null  object
#  76  entorno_salud            95315 non-null  int64
#  77  entorno_familiar         95315 non-null  int64
#  78  entorno_trabajo          95315 non-null  int64
#  79  entorno_desconocido      95315 non-null  int64
#  80  contacto_pais            66668 non-null  object
#  81  mercado                  61719 non-null  object
#  82  mercado_pais             66668 non-null  object
#  83  fecha_mue                95315 non-null  object
#  84  fecha_res                95315 non-null  object
#  85  fecha_mue1               95305 non-null  object
#  86  fecha_res1               95305 non-null  object
#  87  fecha_rap                66657 non-null  object
#  88  muestra_rap              62698 non-null  object
#  89  prueba_rap               61121 non-null  object
#  90  resultado_rap            62727 non-null  object
#  91  fecha_res_rap            62222 non-null  object
#  92  fecha_rap1               66656 non-null  object
# dtypes: float64(7), int64(39), object(47)
# memory usage: 67.6+ MB

# %%
# Obtener el recuento de filas por columna
recuento_filas = df2.count()

# Crear el gráfico de barras
plt.figure(figsize=(12, 16))
recuento_filas.plot(kind='barh', color='skyblue')
plt.title('Recuento de filas por columna')
plt.ylabel('Columnas')
plt.xlabel('Recuento de filas')
plt.yticks(fontsize = 10)

# Especificar las marcas del eje x
plt.xticks(range(0, recuento_filas.max() + 10000, 10000))

plt.grid(True)
plt.tight_layout()  # Ajustar el diseño para evitar superposiciones
plt.show()

# %% [markdown]
# ## Completar valores faltantes

# %%
# Verificar qué columnas tienen al menos un NaN y contarlos
columnas_nan = df2.isna().any()  # Verifica qué columnas tienen al menos un NaN
columnas_nan = columnas_nan[columnas_nan].index  # Filtra solo columnas con NaN
columnas_con_nan = df2[columnas_nan].isna().sum()  # Cuenta los NaN en las columnas identificadas

# Valores únicos
valores_unicos = {}
for columna in columnas_nan:
    valores_unicos[columna] = len(df2[columna].unique())

# Valores no nulos
valores_no_nulos = {}
for columna in columnas_nan:
    valores_no_nulos[columna] = df2[columna].count()

# Tipos de datos
tipos_de_datos = {}
for columna in columnas_nan:
    tipos_de_datos[columna] = df2[columna].dtype

# Crear una tabla
tabla_nan = pd.DataFrame({
    "Columnas": columnas_con_nan.index,
    "Valores No Nulos": [valores_no_nulos[columna] for columna in columnas_con_nan.index],
    "Valores Nulos (NaN)": columnas_con_nan.values,
    "Valores únicos": [valores_unicos[columna] for columna in columnas_con_nan.index],
    "Tipo de datos": [tipos_de_datos[columna] for columna in columnas_con_nan.index]
})

tabla_nan
# Out:
#                    Columnas  Valores No Nulos  Valores Nulos (NaN)  \
# 0                  microred             95218                   97
# 1           establecimiento             95298                   17
# 2               institucion             95298                   17
# 3             clasificacion             95311                    4
# 4                 fecha_det             66668                28647
# 5   departamento_residencia             95294                   21
# 6      provincia_residencia             95294                   21
# 7                residencia             95294                   21
# 8                    ubigeo             95298                   17
# 9                     etnia             79757                15558
# 10              aislamiento             66668                28647
# 11              temperatura             66668                28647
# 12                     coma             66668                28647
# 13                 hepatico             66668                28647
# 14           otra_ocupacion             63701                31614
# 15               viajado_14             66668                28647
# 16                   pais_1             66668                28647
# 17                   pais_2             66668                28647
# 18                   pais_3             66668                28647
# 19                  eess_14             66668                28647
# 20              contacto_14             66668                28647
# 21           contacto_salud             66668                28647
# 22        contacto_familiar             66668                28647
# 23         contacto_trabajo             66668                28647
# 24     contacto_desconocido             66668                28647
# 25            contacto_pais             66668                28647
# 26                  mercado             61719                33596
# 27             mercado_pais             66668                28647
# 28               fecha_mue1             95305                   10
# 29               fecha_res1             95305                   10
# 30                fecha_rap             66657                28658
# 31              muestra_rap             62698                32617
# 32               prueba_rap             61121                34194
# 33            resultado_rap             62727                32588
# 34            fecha_res_rap             62222                33093
# 35               fecha_rap1             66656                28659
#
#     Valores únicos Tipo de datos
# 0               64        object
# 1              345        object
# 2                6        object
# 3                5        object
# 4              220        object
# 5               26        object
# 6              102        object
# 7              327        object
# 8              335        object
# 9                6        object
# 10               3        object
# 11              32       float64
# 12               3       float64
# 13               3       float64
# 14            5971        object
# 15               4        object
# 16              24        object
# 17              16        object
# 18               9        object
# 19               4        object
# 20               4        object
# 21               3       float64
# 22               3       float64
# 23               3       float64
# 24               3       float64
# 25              11        object
# 26               4        object
# 27              20        object
# 28             256        object
# 29             247        object
# 30             263        object
# 31               2        object
# 32             101        object
# 33               5        object
# 34             263        object
# 35             227        object

# %%
df2[df2['microred'].isna()]
# Out:
#             id   ano  semana   fecha_not diresa        red microred  \
# 5901    454875  2020      26  23-06-2020   PUNO       PUNO      NaN
# 6976    533816  2020      25  30-06-2020   PUNO       PUNO      NaN
# 7001    534836  2020      27  30-06-2020   PUNO       PUNO      NaN
# 7053    536496  2020      27  30-06-2020   PUNO       PUNO      NaN
# 7057    536620  2020      27  30-06-2020   PUNO       PUNO      NaN
# 7071    537067  2020      27  30-06-2020   PUNO       PUNO      NaN
# 7085    537600  2020      27  30-06-2020   PUNO       PUNO      NaN
# 7100    538425  2020      27  30-06-2020   PUNO       PUNO      NaN
# 7103    538531  2020      26  30-06-2020   PUNO       PUNO      NaN
# 7107    538634  2020      26  30-06-2020   PUNO       PUNO      NaN
# 7111    538712  2020      27  30-06-2020   PUNO       PUNO      NaN
# 7115    538787  2020      27  30-06-2020   PUNO       PUNO      NaN
# 7160    540186  2020      27  30-06-2020   PUNO       PUNO      NaN
# 7213    544859  2020      27  01-07-2020   PUNO       PUNO      NaN
# 7214    544863  2020      27  01-07-2020   PUNO       PUNO      NaN
# 7290    547429  2020      27  30-06-2020   PUNO       PUNO      NaN
# 7382    551167  2020      26  22-06-2020   PUNO       PUNO      NaN
# 7391    551350  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7404    552140  2020      27  30-06-2020   PUNO       PUNO      NaN
# 7406    552382  2020      27  30-06-2020   PUNO       PUNO      NaN
# 7407    552552  2020      27  30-06-2020   PUNO       PUNO      NaN
# 7412    553443  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7449    557056  2020      27  02-07-2020   PUNO       PUNO      NaN
# 7450    557060  2020      27  02-07-2020   PUNO       PUNO      NaN
# 7453    557075  2020      27  02-07-2020   PUNO       PUNO      NaN
# 7454    557079  2020      27  02-07-2020   PUNO       PUNO      NaN
# 7456    557090  2020      27  02-07-2020   PUNO       PUNO      NaN
# 7458    557098  2020      27  02-07-2020   PUNO       PUNO      NaN
# 7556    570049  2020      27  03-07-2020   PUNO       PUNO      NaN
# 7557    570060  2020      27  03-07-2020   PUNO       PUNO      NaN
# 7564    570306  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7566    570317  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7574    570587  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7584    570887  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7586    570960  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7587    570967  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7591    571067  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7592    571110  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7597    571198  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7616    571825  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7623    572055  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7635    572408  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7639    572531  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7641    572614  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7644    572688  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7657    573206  2020      27  02-07-2020   PUNO       PUNO      NaN
# 7659    573265  2020      26  26-06-2020   PUNO       PUNO      NaN
# 7662    573509  2020      27  02-07-2020   PUNO       PUNO      NaN
# 7665    574117  2020      27  02-07-2020   PUNO       PUNO      NaN
# 7666    574209  2020      27  02-07-2020   PUNO       PUNO      NaN
# 7667    574357  2020      27  02-07-2020   PUNO       PUNO      NaN
# 7673    574854  2020      27  02-07-2020   PUNO       PUNO      NaN
# 7679    575235  2020      27  02-07-2020   PUNO       PUNO      NaN
# 7682    575341  2020      27  02-07-2020   PUNO       PUNO      NaN
# 7710    577772  2020      27  02-07-2020   PUNO       PUNO      NaN
# 7713    577897  2020      27  03-07-2020   PUNO       PUNO      NaN
# 7717    578033  2020      27  04-07-2020   PUNO       PUNO      NaN
# 7720    578180  2020      26  04-07-2020   PUNO       PUNO      NaN
# 7721    578305  2020      26  04-07-2020   PUNO       PUNO      NaN
# 7844    583357  2020      28  05-07-2020   PUNO       PUNO      NaN
# 7847    583370  2020      28  05-07-2020   PUNO       PUNO      NaN
# 7850    583393  2020      28  05-07-2020   PUNO       PUNO      NaN
# 7851    583400  2020      28  05-07-2020   PUNO       PUNO      NaN
# 7854    583444  2020      28  05-07-2020   PUNO       PUNO      NaN
# 7988    590083  2020      26  01-07-2020   PUNO       PUNO      NaN
# 8058    594355  2020      27  01-07-2020   PUNO       PUNO      NaN
# 8059    594422  2020      26  01-07-2020   PUNO       PUNO      NaN
# 8061    595917  2020      28  06-07-2020   PUNO       PUNO      NaN
# 8062    595919  2020      28  06-07-2020   PUNO       PUNO      NaN
# 8063    595932  2020      26  01-07-2020   PUNO       PUNO      NaN
# 8068    596618  2020      26  26-06-2020   PUNO       PUNO      NaN
# 8077    597149  2020      26  26-06-2020   PUNO       PUNO      NaN
# 8114    599529  2020      26  26-06-2020   PUNO       PUNO      NaN
# 8125    600300  2020      26  26-06-2020   PUNO       PUNO      NaN
# 8126    600526  2020      26  26-06-2020   PUNO       PUNO      NaN
# 8166    603913  2020      26  26-06-2020   PUNO       PUNO      NaN
# 8167    604013  2020      26  26-06-2020   PUNO       PUNO      NaN
# 8170    604682  2020      26  26-06-2020   PUNO       PUNO      NaN
# 8171    604827  2020      26  26-06-2020   PUNO       PUNO      NaN
# 8177    605235  2020      26  26-06-2020   PUNO       PUNO      NaN
# 8181    605408  2020      26  26-06-2020   PUNO       PUNO      NaN
# 8210    607366  2020      27  04-07-2020   PUNO       PUNO      NaN
# 21829  2084053  2020      49  19-08-2020   PUNO  SAN ROMAN      NaN
# 64810  5135191  2020      48  01-12-2020   PUNO  SAN ROMAN      NaN
# 65649  5211580  2020      49  06-12-2020   PUNO  SAN ROMAN      NaN
# 67053  5317838  2020      50  06-12-2020   PUNO       PUNO      NaN
# 67065  5318537  2020      43  22-10-2020   PUNO   HUANCANE      NaN
# 67068  5318657  2020      43  22-10-2020   PUNO   HUANCANE      NaN
# 67070  5318818  2020      50  15-12-2020   PUNO  SAN ROMAN      NaN
# 67084  5319769  2020      49  07-12-2020   PUNO      LAMPA      NaN
# 67090  5320545  2020      49  07-12-2020   PUNO      LAMPA      NaN
# 67096  5321319  2020      48  11-12-2020   PUNO      LAMPA      NaN
# 67099  5322992  2020      39  22-10-2020   PUNO   HUANCANE      NaN
# 67107  5324244  2020      51  15-12-2020   PUNO  SAN ROMAN      NaN
# 77993  6898682  2021       9  11-03-2021   PUNO     COLLAO      NaN
# 77994  6898783  2021       9  12-03-2021   PUNO     COLLAO      NaN
# 82624  7401878  2021      13  06-04-2021   PUNO       PUNO      NaN
#
#                                establecimiento  \
# 5901                          HOSP.SANIDAD PNP
# 6976                           POLICLINICO PNP
# 7001                           POLICLINICO PNP
# 7053                           POLICLINICO PNP
# 7057                           POLICLINICO PNP
# 7071                           POLICLINICO PNP
# 7085                           POLICLINICO PNP
# 7100                           POLICLINICO PNP
# 7103                           POLICLINICO PNP
# 7107                           POLICLINICO PNP
# 7111                           POLICLINICO PNP
# 7115                           POLICLINICO PNP
# 7160   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7213   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7214   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7290                           POLICLINICO PNP
# 7382   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7391   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7404   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7406   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7407   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7412                           POLICLINICO PNP
# 7449   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7450   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7453   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7454   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7456   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7458   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7556   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7557   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7564                           POLICLINICO PNP
# 7566                           POLICLINICO PNP
# 7574                           POLICLINICO PNP
# 7584                           POLICLINICO PNP
# 7586                           POLICLINICO PNP
# 7587                           POLICLINICO PNP
# 7591                           POLICLINICO PNP
# 7592                           POLICLINICO PNP
# 7597                           POLICLINICO PNP
# 7616                           POLICLINICO PNP
# 7623                           POLICLINICO PNP
# 7635                           POLICLINICO PNP
# 7639                           POLICLINICO PNP
# 7641                           POLICLINICO PNP
# 7644                           POLICLINICO PNP
# 7657                           POLICLINICO PNP
# 7659                           POLICLINICO PNP
# 7662                           POLICLINICO PNP
# 7665                           POLICLINICO PNP
# 7666                           POLICLINICO PNP
# 7667                           POLICLINICO PNP
# 7673                           POLICLINICO PNP
# 7679                           POLICLINICO PNP
# 7682                           POLICLINICO PNP
# 7710   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7713   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7717   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7720   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7721   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7844   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7847   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7850   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7851   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7854   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 7988   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 8058   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 8059   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 8061   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 8062   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 8063   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 8068                           POLICLINICO PNP
# 8077                           POLICLINICO PNP
# 8114                           POLICLINICO PNP
# 8125                           POLICLINICO PNP
# 8126                           POLICLINICO PNP
# 8166                           POLICLINICO PNP
# 8167                           POLICLINICO PNP
# 8170                           POLICLINICO PNP
# 8171                           POLICLINICO PNP
# 8177                           POLICLINICO PNP
# 8181                           POLICLINICO PNP
# 8210   HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO
# 21829                                      NaN
# 64810                                      NaN
# 65649                                      NaN
# 67053                                      NaN
# 67065                                      NaN
# 67068                                      NaN
# 67070                                      NaN
# 67084                                      NaN
# 67090                                      NaN
# 67096                                      NaN
# 67099                                      NaN
# 67107                                      NaN
# 77993                                      NaN
# 77994                                      NaN
# 82624                                      NaN
#
#                                    institucion clasificacion  ...   fecha_mue  \
# 5901   SANIDAD DE LA POLICIA NACIONAL DEL PERU    CONFIRMADO  ...  14-08-2020
# 6976   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7001   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7053   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7057   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7071   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7085   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7100   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7103   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7107   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7111   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7115   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7160                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7213                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7214                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7290   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7382                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7391                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7404                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7406                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7407                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7412   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7449                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7450                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7453                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7454                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7456                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7458                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7556                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7557                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7564   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7566   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7574   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7584   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7586   SANIDAD DE LA POLICIA NACIONAL DEL PERU    SOSPECHOSO  ...  00-00-0000
# 7587   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7591   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7592   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7597   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7616   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7623   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7635   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7639   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7641   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7644   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7657   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7659   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7662   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7665   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7666   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7667   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7673   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7679   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7682   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 7710                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7713                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7717                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7720                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7721                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7844                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7847                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7850                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7851                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7854                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 7988                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 8058                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 8059                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 8061                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 8062                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 8063                         GOBIERNO REGIONAL    CONFIRMADO  ...  00-00-0000
# 8068   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 8077   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 8114   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 8125   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 8126   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 8166   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 8167   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 8170   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 8171   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 8177   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 8181   SANIDAD DE LA POLICIA NACIONAL DEL PERU    DESCARTADO  ...  00-00-0000
# 8210                         GOBIERNO REGIONAL    DESCARTADO  ...  00-00-0000
# 21829                                      NaN    CONFIRMADO  ...  09-12-2020
# 64810                                      NaN    CONFIRMADO  ...  02-12-2020
# 65649                                      NaN    CONFIRMADO  ...  07-12-2020
# 67053                                      NaN    SOSPECHOSO  ...  06-12-2020
# 67065                                      NaN    SOSPECHOSO  ...  22-10-2020
# 67068                                      NaN    SOSPECHOSO  ...  22-10-2020
# 67070                                      NaN    SOSPECHOSO  ...  15-12-2020
# 67084                                      NaN    DESCARTADO  ...  07-12-2020
# 67090                                      NaN    DESCARTADO  ...  07-12-2020
# 67096                                      NaN    DESCARTADO  ...  11-12-2020
# 67099                                      NaN      PROBABLE  ...  22-10-2020
# 67107                                      NaN    SOSPECHOSO  ...  15-12-2020
# 77993                                      NaN    CONFIRMADO  ...  11-03-2021
# 77994                                      NaN    CONFIRMADO  ...  02-03-2021
# 82624                                      NaN    CONFIRMADO  ...  18-09-2020
#
#         fecha_res  fecha_mue1  fecha_res1   fecha_rap        muestra_rap  \
# 5901   14-08-2020  00-00-0000  00-00-0000  23-06-2020  MUESTRA DE SANGRE
# 6976   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7001   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7053   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7057   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7071   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7085   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7100   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7103   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7107   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7111   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7115   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7160   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7213   00-00-0000  00-00-0000  00-00-0000  01-07-2020  MUESTRA DE SANGRE
# 7214   00-00-0000  00-00-0000  00-00-0000  01-07-2020  MUESTRA DE SANGRE
# 7290   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7382   00-00-0000  00-00-0000  00-00-0000  22-06-2020  MUESTRA DE SANGRE
# 7391   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7404   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7406   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7407   00-00-0000  00-00-0000  00-00-0000  30-06-2020  MUESTRA DE SANGRE
# 7412   00-00-0000  00-00-0000  00-00-0000  25-06-2020  MUESTRA DE SANGRE
# 7449   00-00-0000  00-00-0000  00-00-0000  02-07-2020  MUESTRA DE SANGRE
# 7450   00-00-0000  00-00-0000  00-00-0000  02-07-2020  MUESTRA DE SANGRE
# 7453   00-00-0000  00-00-0000  00-00-0000  02-07-2020  MUESTRA DE SANGRE
# 7454   00-00-0000  00-00-0000  00-00-0000  02-07-2020  MUESTRA DE SANGRE
# 7456   00-00-0000  00-00-0000  00-00-0000  02-07-2020  MUESTRA DE SANGRE
# 7458   00-00-0000  00-00-0000  00-00-0000  02-07-2020  MUESTRA DE SANGRE
# 7556   00-00-0000  00-00-0000  00-00-0000  03-07-2020  MUESTRA DE SANGRE
# 7557   00-00-0000  00-00-0000  00-00-0000  03-07-2020  MUESTRA DE SANGRE
# 7564   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7566   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7574   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7584   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7586   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7587   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7591   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7592   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7597   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7616   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7623   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7635   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7639   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7641   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7644   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7657   00-00-0000  00-00-0000  00-00-0000  02-07-2020  MUESTRA DE SANGRE
# 7659   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 7662   00-00-0000  00-00-0000  00-00-0000  02-07-2020  MUESTRA DE SANGRE
# 7665   00-00-0000  00-00-0000  00-00-0000  02-07-2020  MUESTRA DE SANGRE
# 7666   00-00-0000  00-00-0000  00-00-0000  02-07-2020  MUESTRA DE SANGRE
# 7667   00-00-0000  00-00-0000  00-00-0000  02-07-2020  MUESTRA DE SANGRE
# 7673   00-00-0000  00-00-0000  00-00-0000  02-07-2020  MUESTRA DE SANGRE
# 7679   00-00-0000  00-00-0000  00-00-0000  02-07-2020  MUESTRA DE SANGRE
# 7682   00-00-0000  00-00-0000  00-00-0000  02-07-2020  MUESTRA DE SANGRE
# 7710   00-00-0000  00-00-0000  00-00-0000  02-07-2020  MUESTRA DE SANGRE
# 7713   00-00-0000  00-00-0000  00-00-0000  03-07-2020  MUESTRA DE SANGRE
# 7717   00-00-0000  00-00-0000  00-00-0000  04-07-2020  MUESTRA DE SANGRE
# 7720   00-00-0000  00-00-0000  00-00-0000  04-07-2020  MUESTRA DE SANGRE
# 7721   00-00-0000  00-00-0000  00-00-0000  04-07-2020                NaN
# 7844   00-00-0000  00-00-0000  00-00-0000  05-07-2020  MUESTRA DE SANGRE
# 7847   00-00-0000  00-00-0000  00-00-0000  05-07-2020  MUESTRA DE SANGRE
# 7850   00-00-0000  00-00-0000  00-00-0000  05-07-2020  MUESTRA DE SANGRE
# 7851   00-00-0000  00-00-0000  00-00-0000  05-07-2020  MUESTRA DE SANGRE
# 7854   00-00-0000  00-00-0000  00-00-0000  05-07-2020  MUESTRA DE SANGRE
# 7988   00-00-0000  00-00-0000  00-00-0000  01-07-2020  MUESTRA DE SANGRE
# 8058   00-00-0000  00-00-0000  00-00-0000  01-07-2020  MUESTRA DE SANGRE
# 8059   00-00-0000  00-00-0000  00-00-0000  01-07-2020  MUESTRA DE SANGRE
# 8061   00-00-0000  00-00-0000  00-00-0000  06-07-2020  MUESTRA DE SANGRE
# 8062   00-00-0000  00-00-0000  00-00-0000  06-07-2020  MUESTRA DE SANGRE
# 8063   00-00-0000  00-00-0000  00-00-0000  06-07-2020  MUESTRA DE SANGRE
# 8068   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 8077   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 8114   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 8125   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 8126   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 8166   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 8167   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 8170   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 8171   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 8177   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 8181   00-00-0000  00-00-0000  00-00-0000  26-06-2020  MUESTRA DE SANGRE
# 8210   00-00-0000  00-00-0000  00-00-0000  04-07-2020  MUESTRA DE SANGRE
# 21829  11-12-2020  00-00-0000  00-00-0000  19-08-2020  MUESTRA DE SANGRE
# 64810  03-12-2020  00-00-0000  00-00-0000  01-12-2020  MUESTRA DE SANGRE
# 65649  11-12-2020  00-00-0000  00-00-0000  03-12-2020  MUESTRA DE SANGRE
# 67053  06-12-2020  00-00-0000  00-00-0000         NaN                NaN
# 67065  26-10-2020  00-00-0000  00-00-0000         NaN                NaN
# 67068  22-10-2020  00-00-0000  00-00-0000         NaN                NaN
# 67070  15-12-2020  00-00-0000  00-00-0000         NaN                NaN
# 67084  08-12-2020  00-00-0000  00-00-0000         NaN                NaN
# 67090  08-12-2020  00-00-0000  00-00-0000         NaN                NaN
# 67096  12-12-2020  00-00-0000  00-00-0000         NaN                NaN
# 67099  26-10-2020  00-00-0000  00-00-0000         NaN                NaN
# 67107  15-12-2020  00-00-0000  00-00-0000         NaN                NaN
# 77993  11-03-2021  00-00-0000  00-00-0000         NaN                NaN
# 77994  02-03-2021  00-00-0000  00-00-0000         NaN                NaN
# 82624  18-09-2020  06-04-2021  06-04-2021         NaN                NaN
#
#           prueba_rap          resultado_rap fecha_res_rap  fecha_rap1
# 5901      SEROLOGICA               NEGATIVO    23-06-2020  13-08-2020
# 6976      SEROLOGICA               NEGATIVO    30-06-2020  00-00-0000
# 7001      SEROLOGICA               NEGATIVO    30-06-2020  00-00-0000
# 7053      SEROLOGICA               NEGATIVO    30-06-2020  00-00-0000
# 7057      SEROLOGICA               NEGATIVO    30-06-2020  00-00-0000
# 7071      SEROLOGICA               NEGATIVO    30-06-2020  00-00-0000
# 7085      SEROLOGICA               NEGATIVO    30-06-2020  00-00-0000
# 7100      SEROLOGICA               NEGATIVO    30-06-2020  00-00-0000
# 7103      SEROLOGICA               NEGATIVO    30-06-2020  00-00-0000
# 7107      SEROLOGICA               NEGATIVO    30-06-2020  00-00-0000
# 7111      SEROLOGICA               NEGATIVO    30-06-2020  00-00-0000
# 7115      SEROLOGICA               NEGATIVO    30-06-2020  00-00-0000
# 7160   Prueba Rapida               NEGATIVO    30-06-2020  00-00-0000
# 7213   prueba rapida               NEGATIVO    01-07-2020  00-00-0000
# 7214   prueba rapida               NEGATIVO    01-07-2020  00-00-0000
# 7290      SEROLOGICA               NEGATIVO    30-06-2020  00-00-0000
# 7382   Prueba Rapida               NEGATIVO    22-06-2020  00-00-0000
# 7391   Prueba Rapida               NEGATIVO    26-06-2020  00-00-0000
# 7404   Prueba Rapida               NEGATIVO    30-06-2020  00-00-0000
# 7406   Prueba Rapida               NEGATIVO    30-06-2020  00-00-0000
# 7407   Prueba Rapida               NEGATIVO    30-06-2020  00-00-0000
# 7412      SEROLOGICA               NEGATIVO    25-06-2020  00-00-0000
# 7449   prueba rapida               NEGATIVO    02-07-2020  00-00-0000
# 7450   prueba rapida               NEGATIVO    02-07-2020  00-00-0000
# 7453   prueba rapida               NEGATIVO    02-07-2020  00-00-0000
# 7454   prueba rapida               NEGATIVO    02-07-2020  00-00-0000
# 7456   prueba rapida               NEGATIVO    02-07-2020  00-00-0000
# 7458   prueba rapida               NEGATIVO    02-07-2020  00-00-0000
# 7556      SEROLOGICO               NEGATIVO    03-07-2020  00-00-0000
# 7557      SEROLOGICO               NEGATIVO    03-07-2020  00-00-0000
# 7564      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7566      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7574      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7584      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7586      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7587      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7591      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7592      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7597      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7616      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7623      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7635      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7639      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7641      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7644      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7657      SEROLOGICA               NEGATIVO    02-07-2020  00-00-0000
# 7659      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 7662      SEROLOGICA               NEGATIVO    02-07-2020  00-00-0000
# 7665      SEROLOGICA               NEGATIVO    02-07-2020  00-00-0000
# 7666      SEROLOGICA               NEGATIVO    02-07-2020  00-00-0000
# 7667      SEROLOGICA               NEGATIVO    02-07-2020  00-00-0000
# 7673      SEROLOGICA               NEGATIVO    02-07-2020  00-00-0000
# 7679      SEROLOGICA               NEGATIVO    02-07-2020  00-00-0000
# 7682      SEROLOGICA               NEGATIVO    02-07-2020  00-00-0000
# 7710   Prueba Rapida               NEGATIVO    02-07-2020  00-00-0000
# 7713   Prueba Rapida               NEGATIVO    03-07-2020  00-00-0000
# 7717   Prueba Rapida               NEGATIVO    04-07-2020  00-00-0000
# 7720   Prueba Rapida               NEGATIVO    04-07-2020  00-00-0000
# 7721   Prueba Rapida                    NaN    04-07-2020  00-00-0000
# 7844      SEROLOGICO               NEGATIVO    05-07-2020  00-00-0000
# 7847      SEROLOGICO               NEGATIVO    05-07-2020  00-00-0000
# 7850      SEROLOGICO               NEGATIVO    05-07-2020  00-00-0000
# 7851      SEROLOGICO               NEGATIVO    05-07-2020  00-00-0000
# 7854      SEROLOGICO               NEGATIVO    05-07-2020  00-00-0000
# 7988      SEROLOGICO               NEGATIVO    01-07-2020  00-00-0000
# 8058   Prueba Rapida               NEGATIVO    01-07-2020  00-00-0000
# 8059   Prueba Rapida               NEGATIVO    01-07-2020  00-00-0000
# 8061      SEROLOGICO               NEGATIVO    06-07-2020  00-00-0000
# 8062      SEROLOGICO               NEGATIVO    06-07-2020  00-00-0000
# 8063      SEROLOGICO          Ig G POSITIVO           NaN  00-00-0000
# 8068      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 8077      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 8114      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 8125      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 8126      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 8166      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 8167      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 8170      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 8171      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 8177      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 8181      SEROLOGICA               NEGATIVO    26-06-2020  00-00-0000
# 8210      Serologico               NEGATIVO    04-07-2020  00-00-0000
# 21829  PRUEBA RÁPIDA  Ig M  e Ig G POSITIVO    19-08-2020  00-00-0000
# 64810  PRUEBA RÁPIDA  Ig M  e Ig G POSITIVO    01-12-2020  00-00-0000
# 65649  PRUEBA RÁPIDA               NEGATIVO    03-12-2020  00-00-0000
# 67053            NaN                    NaN           NaN         NaN
# 67065            NaN                    NaN           NaN         NaN
# 67068            NaN                    NaN           NaN         NaN
# 67070            NaN                    NaN           NaN         NaN
# 67084            NaN                    NaN           NaN         NaN
# 67090            NaN                    NaN           NaN         NaN
# 67096            NaN                    NaN           NaN         NaN
# 67099            NaN                    NaN           NaN         NaN
# 67107            NaN                    NaN           NaN         NaN
# 77993            NaN                    NaN           NaN         NaN
# 77994            NaN                    NaN           NaN         NaN
# 82624            NaN                    NaN           NaN         NaN
#
# [97 rows x 93 columns]

# %%
print(df2['microred'].unique())
# Out:
# ['SIN MICRORED' 'METROPOLITANO' 'JOSÉ ANTONIO ENCINAS' 'CABANILLA'
#  'DESAGUADERO' 'ZEPITA' 'ÁCORA' 'TARACO' 'SIMÓN BOLIVAR' 'ORURILLO'
#  'NUÑOA' 'HUANCANÉ' 'AYAPATA' 'SANTA ADRIANA' 'CAPACHICA' 'POMATA'
#  'JULIACA' 'COJATA' 'ARAPA' 'SAN ANTÓN' 'ILAVE' 'MAÑAZO'
#  'JOSÉ DOMINGO CHOQUEHUANCA' 'ASILLO' 'COPANI' 'OLLARAYA' 'YUNGUYO'
#  'SAN PEDRO DE PUTINA PUNCO' 'MOLINO' 'ALIANZA' 'CONO SUR' 'CHUPA'
#  'MUÑANI' 'SANTA LUCÍA' 'LARAQUERI' 'SAN GABÁN' 'AJOYANI' 'MASIAPO'
#  'CRUCERO' 'MOHO' 'PUTINA' 'AYAVIRI' 'PILCUYO' 'PALCA' 'SAMÁN' 'MAZOCRUZ'
#  'CABANILLAS' 'ANANEA' 'CHECCA' nan 'SAN JUAN DEL ORO' 'ISIVILLA' 'PHARA'
#  'LAMPA' 'COASA' 'SANTA ROSA' 'CONIMA' 'LLALLI' 'VILQUECHICO' 'CAMICHACHI'
#  'ROSASPATA' 'CUYO CUYO' 'SANDIA' 'AYCHUYO']

# %% [markdown]
# ### Valores Numéricos

# %%
df2.loc[df['temperatura'] == 0, 'temperatura'] = 36

# %%
valores_numericos = ['temperatura', 'coma', 'hepatico', 'contacto_salud', 'contacto_familiar', 'contacto_trabajo', 'contacto_desconocido']

# %%
df3 = df2.copy()
for columna in valores_numericos:
    mediana = df3[columna].median()
    print(columna, "=", mediana)
    df3[columna] = df3[columna].fillna(mediana)
# Out:
# temperatura = 36.0
# coma = 0.0
# hepatico = 0.0
# contacto_salud = 0.0
# contacto_familiar = 0.0
# contacto_trabajo = 0.0
# contacto_desconocido = 0.0

# %% [markdown]
# ### Valores Categóricos

# %%
dicc_valores_categorico = {
    'microred' : 'SIN MICRORED',
    'establecimiento' : 'SIN REGISTRO',
    'institucion' : 'SIN REGISTRO',
    'clasificacion' : 'SIN REGISTRO',
    'fecha_det' : '00-00-0000',
    'departamento_residencia' : 'SIN REGISTRO',
    'provincia_residencia' : 'SIN REGISTRO',
    'residencia' : 'SIN REGISTRO',
    'ubigeo' : 'SIN REGISTRO',
    'etnia' : 'Otro',
    'aislamiento' : 'DESCONOCIDO',
    'otra_ocupacion' : 'SIN SEGUNDA OCUPACION',
    'viajado_14' : 'DESCONOCIDO',
    'pais_1' : 'Sin registro',
    'pais_2' : 'Sin registro',
    'pais_3' : 'Sin registro',
    'eess_14' : 'DESCONOCIDO',
    'contacto_14' : 'DESCONOCIDO',
    'contacto_pais' : 'Sin registro',
    'mercado' : 'DESCONOCIDO',
    'mercado_pais' : 'Sin registro',
    'fecha_mue1' : '00-00-0000',
    'fecha_res1' : '00-00-0000',
    'fecha_rap' : '00-00-0000',
    'muestra_rap' : 'DESCONOCIDO',
    'prueba_rap' : 'DESCONOCIDO',
    'resultado_rap' : 'DESCONOCIDO',
    'fecha_res_rap' : '00-00-0000',
    'fecha_rap1' : '00-00-0000'
}

# %%
for x, y in dicc_valores_categorico.items():
    df3[x] = df3[x].fillna(y)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95315 entries, 0 to 95314
# Data columns (total 93 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       95315 non-null  int64
#  1   ano                      95315 non-null  int64
#  2   semana                   95315 non-null  int64
#  3   fecha_not                95315 non-null  object
#  4   diresa                   95315 non-null  object
#  5   red                      95315 non-null  object
#  6   microred                 95315 non-null  object
#  7   establecimiento          95315 non-null  object
#  8   institucion              95315 non-null  object
#  9   clasificacion            95315 non-null  object
#  10  fecha_det                95315 non-null  object
#  11  nombre                   95315 non-null  object
#  12  edad                     95315 non-null  int64
#  13  tipo_edad                95315 non-null  object
#  14  sexo                     95315 non-null  object
#  15  tipodoc                  95315 non-null  object
#  16  pais_residencia          95315 non-null  object
#  17  departamento_residencia  95315 non-null  object
#  18  provincia_residencia     95315 non-null  object
#  19  residencia               95315 non-null  object
#  20  ubigeo                   95315 non-null  object
#  21  etnia                    95315 non-null  object
#  22  direccion                95315 non-null  object
#  23  fecha_ini                95315 non-null  object
#  24  hospitalizado            95315 non-null  object
#  25  fecha_hos                95315 non-null  object
#  26  aislamiento              95315 non-null  object
#  27  fecha_ais                95315 non-null  object
#  28  fecha_def                95315 non-null  object
#  29  fiebre                   95315 non-null  int64
#  30  malestar                 95315 non-null  int64
#  31  tos                      95315 non-null  int64
#  32  garganta                 95315 non-null  int64
#  33  congestion               95315 non-null  int64
#  34  respiratoria             95315 non-null  int64
#  35  diarrea                  95315 non-null  int64
#  36  nauseas                  95315 non-null  int64
#  37  cefalea                  95315 non-null  int64
#  38  irritabilidad            95315 non-null  int64
#  39  muscular                 95315 non-null  int64
#  40  abdominal                95315 non-null  int64
#  41  pecho                    95315 non-null  int64
#  42  articulaciones           95315 non-null  int64
#  43  temperatura              95315 non-null  float64
#  44  exudado                  95315 non-null  int64
#  45  conjuntival              95315 non-null  int64
#  46  convulsion               95315 non-null  int64
#  47  coma                     95315 non-null  float64
#  48  disnea                   95315 non-null  int64
#  49  auscultacion             95315 non-null  int64
#  50  rxpulmonar               95315 non-null  int64
#  51  embarazo                 95315 non-null  int64
#  52  trimestre                95315 non-null  int64
#  53  postparto                95315 non-null  int64
#  54  cardiovascular           95315 non-null  int64
#  55  diabetes                 95315 non-null  int64
#  56  hepatica                 95315 non-null  int64
#  57  neurologica              95315 non-null  int64
#  58  inmunodeficiencia        95315 non-null  int64
#  59  renal                    95315 non-null  int64
#  60  hepatico                 95315 non-null  float64
#  61  pulmonar                 95315 non-null  int64
#  62  cancer                   95315 non-null  int64
#  63  ocupacion                95315 non-null  object
#  64  otra_ocupacion           95315 non-null  object
#  65  viajado_14               95315 non-null  object
#  66  pais_1                   95315 non-null  object
#  67  pais_2                   95315 non-null  object
#  68  pais_3                   95315 non-null  object
#  69  eess_14                  95315 non-null  object
#  70  contacto_14              95315 non-null  object
#  71  contacto_salud           95315 non-null  float64
#  72  contacto_familiar        95315 non-null  float64
#  73  contacto_trabajo         95315 non-null  float64
#  74  contacto_desconocido     95315 non-null  float64
#  75  confirmado_14            95315 non-null  object
#  76  entorno_salud            95315 non-null  int64
#  77  entorno_familiar         95315 non-null  int64
#  78  entorno_trabajo          95315 non-null  int64
#  79  entorno_desconocido      95315 non-null  int64
#  80  contacto_pais            95315 non-null  object
#  81  mercado                  95315 non-null  object
#  82  mercado_pais             95315 non-null  object
#  83  fecha_mue                95315 non-null  object
#  84  fecha_res                95315 non-null  object
#  85  fecha_mue1               95315 non-null  object
#  86  fecha_res1               95315 non-null  object
#  87  fecha_rap                95315 non-null  object
#  88  muestra_rap              95315 non-null  object
#  89  prueba_rap               95315 non-null  object
#  90  resultado_rap            95315 non-null  object
#  91  fecha_res_rap            95315 non-null  object
#  92  fecha_rap1               95315 non-null  object
# dtypes: float64(7), int64(39), object(47)
# memory usage: 67.6+ MB

# %%
# Obtener el recuento de filas por columna
recuento_filas = df3.count()

# Crear el gráfico de barras
plt.figure(figsize=(12, 16))
recuento_filas.plot(kind='barh', color='skyblue')
plt.title('Recuento de filas por columna')
plt.ylabel('Columnas')
plt.xlabel('Recuento de filas')
plt.yticks(fontsize = 10)

# Especificar las marcas del eje x
plt.xticks(range(0, recuento_filas.max() + 10000, 10000))


plt.grid(True)
plt.tight_layout()  # Ajusta el diseño para evitar superposiciones
plt.show()

# %% [markdown]
# ### Valores secundarios

# %%
df4 = df3.copy()

# %%
# Calcular la edad en grupos (por ejemplo, niños, adultos, ancianos)
bins = [0, 5, 12, 18, 28, 65, float('inf')]
labels = ['Primera infancia', 'Infancia', 'Adolescencia', 'Juventud', 'Adultez', 'Vejez']
df4['grupo_etario'] = pd.cut(df4['edad'], bins=bins, labels=labels, right=False)

# Analizar la frecuencia de síntomas
sintomas = ['fiebre', 'tos', 'malestar', 'garganta', 'congestion', 'respiratoria', 'diarrea', 'cefalea', 'irritabilidad', 'muscular', 'abdominal', 'pecho', 'articulaciones']
df4['total_sintomas'] = df4[sintomas].sum(axis=1)

# Determinar si el paciente tiene al menos un síntoma reportado
df4['tiene_sintomas'] = df4[sintomas].any(axis=1)

# Calcular la cantidad de contactos totales (sumando todos los tipos de contactos)
tipos_contacto = ['contacto_salud', 'contacto_familiar', 'contacto_trabajo', 'contacto_desconocido']
df4['total_contactos'] = df4[tipos_contacto].sum(axis=1)

# Determinar si el paciente ha estado en contacto con alguien que ha viajado recientemente
df4['contacto_viaje'] = df4['contacto_pais'] != 'Sin registro'

# Determinar si el paciente tiene al menos un síntoma grave (como fiebre alta o dificultad para respirar)
df4['sintoma_grave'] = (df4['fiebre'] == 1) & (df4['disnea'] == 1)

# Mostrar las primeras filas del DataFrame con los nuevos datos derivados
df4.head()
# Out:
#      id   ano  semana   fecha_not diresa        red       microred  \
# 0   542  2021       5  09-02-2021   PUNO       PUNO   SIN MICRORED
# 1  1234  2020      10  07-03-2020   PUNO  SAN ROMAN   SIN MICRORED
# 2  1258  2020      10  09-03-2020   PUNO       PUNO   SIN MICRORED
# 3  1266  2020      10  09-03-2020   PUNO  SAN ROMAN   SIN MICRORED
# 4  1292  2021       9  05-03-2021   PUNO       PUNO  METROPOLITANO
#
#                            establecimiento        institucion clasificacion  \
# 0  HOSP. REG. "MANUEL NUÑEZ BUTRÓN" - PUNO  GOBIERNO REGIONAL    DESCARTADO
# 1   HOSP. "CARLOS MONGE MEDRANO" - JULIACA  GOBIERNO REGIONAL    DESCARTADO
# 2                  HOSPITAL III DE ESSALUD            ESSALUD    DESCARTADO
# 3   HOSP. "CARLOS MONGE MEDRANO" - JULIACA  GOBIERNO REGIONAL    DESCARTADO
# 4                  C.S. METROPOLITANO PUNO  GOBIERNO REGIONAL    CONFIRMADO
#
#    ...   prueba_rap resultado_rap  fecha_res_rap  fecha_rap1 grupo_etario  \
# 0  ...  DESCONOCIDO   DESCONOCIDO     00-00-0000  00-00-0000      Adultez
# 1  ...  DESCONOCIDO   DESCONOCIDO     00-00-0000  00-00-0000      Adultez
# 2  ...  DESCONOCIDO   DESCONOCIDO     00-00-0000  00-00-0000      Adultez
# 3  ...  DESCONOCIDO   DESCONOCIDO     00-00-0000  00-00-0000        Vejez
# 4  ...    SEROLOGIA      NEGATIVO     16-07-2020  00-00-0000      Adultez
#
#   total_sintomas tiene_sintomas total_contactos contacto_viaje sintoma_grave
# 0              2           True             0.0          False         False
# 1              7           True             0.0           True         False
# 2              2           True             0.0          False         False
# 3              5           True             0.0          False         False
# 4              4           True             0.0          False         False
#
# [5 rows x 99 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95315 entries, 0 to 95314
# Data columns (total 99 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       95315 non-null  int64
#  1   ano                      95315 non-null  int64
#  2   semana                   95315 non-null  int64
#  3   fecha_not                95315 non-null  object
#  4   diresa                   95315 non-null  object
#  5   red                      95315 non-null  object
#  6   microred                 95315 non-null  object
#  7   establecimiento          95315 non-null  object
#  8   institucion              95315 non-null  object
#  9   clasificacion            95315 non-null  object
#  10  fecha_det                95315 non-null  object
#  11  nombre                   95315 non-null  object
#  12  edad                     95315 non-null  int64
#  13  tipo_edad                95315 non-null  object
#  14  sexo                     95315 non-null  object
#  15  tipodoc                  95315 non-null  object
#  16  pais_residencia          95315 non-null  object
#  17  departamento_residencia  95315 non-null  object
#  18  provincia_residencia     95315 non-null  object
#  19  residencia               95315 non-null  object
#  20  ubigeo                   95315 non-null  object
#  21  etnia                    95315 non-null  object
#  22  direccion                95315 non-null  object
#  23  fecha_ini                95315 non-null  object
#  24  hospitalizado            95315 non-null  object
#  25  fecha_hos                95315 non-null  object
#  26  aislamiento              95315 non-null  object
#  27  fecha_ais                95315 non-null  object
#  28  fecha_def                95315 non-null  object
#  29  fiebre                   95315 non-null  int64
#  30  malestar                 95315 non-null  int64
#  31  tos                      95315 non-null  int64
#  32  garganta                 95315 non-null  int64
#  33  congestion               95315 non-null  int64
#  34  respiratoria             95315 non-null  int64
#  35  diarrea                  95315 non-null  int64
#  36  nauseas                  95315 non-null  int64
#  37  cefalea                  95315 non-null  int64
#  38  irritabilidad            95315 non-null  int64
#  39  muscular                 95315 non-null  int64
#  40  abdominal                95315 non-null  int64
#  41  pecho                    95315 non-null  int64
#  42  articulaciones           95315 non-null  int64
#  43  temperatura              95315 non-null  float64
#  44  exudado                  95315 non-null  int64
#  45  conjuntival              95315 non-null  int64
#  46  convulsion               95315 non-null  int64
#  47  coma                     95315 non-null  float64
#  48  disnea                   95315 non-null  int64
#  49  auscultacion             95315 non-null  int64
#  50  rxpulmonar               95315 non-null  int64
#  51  embarazo                 95315 non-null  int64
#  52  trimestre                95315 non-null  int64
#  53  postparto                95315 non-null  int64
#  54  cardiovascular           95315 non-null  int64
#  55  diabetes                 95315 non-null  int64
#  56  hepatica                 95315 non-null  int64
#  57  neurologica              95315 non-null  int64
#  58  inmunodeficiencia        95315 non-null  int64
#  59  renal                    95315 non-null  int64
#  60  hepatico                 95315 non-null  float64
#  61  pulmonar                 95315 non-null  int64
#  62  cancer                   95315 non-null  int64
#  63  ocupacion                95315 non-null  object
#  64  otra_ocupacion           95315 non-null  object
#  65  viajado_14               95315 non-null  object
#  66  pais_1                   95315 non-null  object
#  67  pais_2                   95315 non-null  object
#  68  pais_3                   95315 non-null  object
#  69  eess_14                  95315 non-null  object
#  70  contacto_14              95315 non-null  object
#  71  contacto_salud           95315 non-null  float64
#  72  contacto_familiar        95315 non-null  float64
#  73  contacto_trabajo         95315 non-null  float64
#  74  contacto_desconocido     95315 non-null  float64
#  75  confirmado_14            95315 non-null  object
#  76  entorno_salud            95315 non-null  int64
#  77  entorno_familiar         95315 non-null  int64
#  78  entorno_trabajo          95315 non-null  int64
#  79  entorno_desconocido      95315 non-null  int64
#  80  contacto_pais            95315 non-null  object
#  81  mercado                  95315 non-null  object
#  82  mercado_pais             95315 non-null  object
#  83  fecha_mue                95315 non-null  object
#  84  fecha_res                95315 non-null  object
#  85  fecha_mue1               95315 non-null  object
#  86  fecha_res1               95315 non-null  object
#  87  fecha_rap                95315 non-null  object
#  88  muestra_rap              95315 non-null  object
#  89  prueba_rap               95315 non-null  object
#  90  resultado_rap            95315 non-null  object
#  91  fecha_res_rap            95315 non-null  object
#  92  fecha_rap1               95315 non-null  object
#  93  grupo_etario             95315 non-null  category
#  94  total_sintomas           95315 non-null  int64
#  95  tiene_sintomas           95315 non-null  bool
#  96  total_contactos          95315 non-null  float64
#  97  contacto_viaje           95315 non-null  bool
#  98  sintoma_grave            95315 non-null  bool
# dtypes: bool(3), category(1), float64(8), int64(40), object(47)
# memory usage: 69.4+ MB

# %% [markdown]
# ## Exportar datos

# %%
# Guardar el DataFrame codificado en un nuevo archivo CSV
df4.to_csv('data/data-covid-limpio.csv', index=False)
